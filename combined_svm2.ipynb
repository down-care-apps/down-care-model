# %%
import os
import cv2
import numpy as np
import dlib
from skimage.feature import local_binary_pattern
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import time

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

down_syndrome_path = 'downSyndrome'
healthy_path = 'healty'

RADIUS = 1
POINTS = 8 * RADIUS
METHOD = 'uniform'
PATCH_SIZE = 32

landmark_indices = [36, 39, 42, 45, 27, 30, 33, 31, 35, 51, 48, 54, 57, 68]

pairs = [
    (36, 39), (39, 42), (42, 45), (27, 30), (30, 33), (33, 31),
    (33, 35), (30, 31), (30, 35), (33, 51), (51, 48), (51, 54),
    (51, 57), (48, 57), (54, 57), (39, 68), (42, 68)
]

# %%
def is_frontal_face(landmarks):
    left_eye = np.mean(np.array(landmarks[36:42]), axis=0)
    right_eye = np.mean(np.array(landmarks[42:48]), axis=0)
    nose_tip = np.array(landmarks[30])
    eye_distance = np.linalg.norm(left_eye - right_eye)
    nose_to_left_eye = np.linalg.norm(nose_tip - left_eye)
    nose_to_right_eye = np.linalg.norm(nose_tip - right_eye)
    symmetry_threshold = 0.3 * eye_distance
    return abs(nose_to_left_eye - nose_to_right_eye) < symmetry_threshold

def get_landmarks(image_input):
    gray = cv2.cvtColor(image_input, cv2.COLOR_BGR2GRAY)
    faces = detector(gray)
    for face in faces:
        landmarks = predictor(gray, face)
        points = [(landmarks.part(n).x, landmarks.part(n).y) for n in range(68)]
        midpoint_x = (points[21][0] + points[22][0]) // 2
        midpoint_y = (points[21][1] + points[22][1]) // 2
        points.append((midpoint_x, midpoint_y))
        if is_frontal_face(points):
            return points
    return None

def augment_image(image):
    augmented_images = []
    augmented_images.append(cv2.flip(image, 1))  # Flip horizontally
    rows, cols = image.shape[:2]
    for angle in [-15, -10, 0, 10, 15]:  # Rotate
        M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)
        augmented_images.append(cv2.warpAffine(image, M, (cols, rows)))
    noise = np.random.normal(0, 10, image.shape).astype(np.uint8)  # Add Gaussian noise
    augmented_images.append(cv2.add(image, noise))
    return augmented_images

def extract_patches(image, landmarks, indices, patch_size=PATCH_SIZE):
    patches = []
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    for idx in indices:
        (x, y) = landmarks[idx]
        x_start = max(x - patch_size // 2, 0)
        y_start = max(y - patch_size // 2, 0)
        x_end = min(x + patch_size // 2, gray.shape[1])
        y_end = min(y + patch_size // 2, gray.shape[0])
        patch = gray[y_start:y_end, x_start:x_end]
        if patch.size > 0:
            patches.append(patch)
    return patches

def extract_lbp_from_patches(patches, radius=RADIUS, points=POINTS, method=METHOD):
    lbp_features = []
    for patch in patches:
        lbp = local_binary_pattern(patch, points, radius, method)
        hist, _ = np.histogram(lbp.ravel(), bins=np.arange(0, points + 3), range=(0, points + 2))
        hist = hist.astype("float")
        hist /= (hist.sum() + 1e-6)
        lbp_features.extend(hist)
    return lbp_features

def extract_geometric_features(landmarks, pairs):
    geom_features = []
    for i, j in pairs:
        p1 = landmarks[i]
        p2 = landmarks[j]
        distance = np.linalg.norm(np.array(p1) - np.array(p2))
        geom_features.append(distance)
    return geom_features

def align_face(image, landmarks):
    if landmarks is None or len(landmarks) < 68:
        raise ValueError("Landmarks are invalid or incomplete.")
    
    # Convert landmarks to numpy array
    landmarks = np.array(landmarks, dtype=np.float32)

    # Calculate the center of the left and right eyes
    left_eye_center = np.mean(landmarks[36:42], axis=0)
    right_eye_center = np.mean(landmarks[42:48], axis=0)

    # Calculate the angle between the eye centers
    dy = right_eye_center[1] - left_eye_center[1]
    dx = right_eye_center[0] - left_eye_center[0]
    angle = np.degrees(np.arctan2(dy, dx))

    # Calculate the center point between the two eyes
    eye_center = tuple(np.mean([left_eye_center, right_eye_center], axis=0))

    # Get the rotation matrix for the alignment
    rotation_matrix = cv2.getRotationMatrix2D(eye_center, angle, scale=1.0)

    # Perform the alignment
    aligned_image = cv2.warpAffine(
        image, 
        rotation_matrix, 
        (image.shape[1], image.shape[0]),
        flags=cv2.INTER_LINEAR
    )

    # Transform the landmarks to match the aligned image
    ones = np.ones((landmarks.shape[0], 1), dtype=np.float32)  # Homogeneous coordinates
    landmarks_hom = np.hstack([landmarks, ones])
    transformed_landmarks = rotation_matrix @ landmarks_hom.T
    transformed_landmarks = transformed_landmarks[:2].T  # Convert back to (x, y) format

    return aligned_image, transformed_landmarks

def crop_face(image, landmarks, padding_percentage=0.1):
    min_x = min(landmarks, key=lambda x: x[0])[0]
    max_x = max(landmarks, key=lambda x: x[0])[0]
    min_y = min(landmarks, key=lambda x: x[1])[1]
    max_y = max(landmarks, key=lambda x: x[1])[1]

    width = max_x - min_x
    height = max_y - min_y
    max_dimension = max(width, height)

    padding = int(max_dimension * padding_percentage)
    center_x = (min_x + max_x) // 2
    center_y = (min_y + max_y) // 2

    available_left = min_x
    available_right = image.shape[1] - max_x
    available_top = min_y
    available_bottom = image.shape[0] - max_y

    if available_left >= padding and available_right >= padding and available_top >= padding and available_bottom >= padding:
        actual_padding = padding
    else:
        actual_padding = min(available_left, available_right, available_top, available_bottom)

    size = max_dimension + actual_padding * 2

    new_min_x = max(int(center_x - size // 2), 0)
    new_max_x = min(int(center_x + size // 2), image.shape[1])
    new_min_y = max(int(center_y - size // 2), 0)
    new_max_y = min(int(center_y + size // 2), image.shape[0])

    cropped_image = image[new_min_y:new_max_y, new_min_x:new_max_x]
    cropped_image_resized = cv2.resize(cropped_image, (300, 300))

    return cropped_image_resized

def get_combined_features(image, pairs):
    landmarks = get_landmarks(image)
    if landmarks is None or len(landmarks) < 68:
        return None

    try:
        aligned_image, aligned_landmarks = align_face(image, landmarks)
    except ValueError as e:
        print(f"Error in alignment: {e}")
        return None

    cropped_image = crop_face(aligned_image, aligned_landmarks)

    cropped_landmarks = get_landmarks(cropped_image)
    if cropped_landmarks is None or len(cropped_landmarks) < 68:
        return None

    patches = extract_patches(cropped_image, cropped_landmarks, landmark_indices)
    lbp_features = extract_lbp_from_patches(patches)
    geom_features = extract_geometric_features(cropped_landmarks, pairs)

    combined_features = lbp_features + geom_features
    return combined_features

# %%
X = []
y = []

for path, label in [(down_syndrome_path, 1), (healthy_path, 0)]:
    for img_file in os.listdir(path):
        img_path = os.path.join(path, img_file)
        img = cv2.imread(img_path)
        if img is not None:
            combined_features = get_combined_features(img, pairs)
            if combined_features:
                X.append(combined_features)
                y.append(label)

                # Apply data augmentation
                augmented_images = augment_image(img)
                for aug_img in augmented_images:
                    aug_features = get_combined_features(aug_img, pairs)
                    if aug_features:
                        X.append(aug_features)
                        y.append(label)
# Out:
# Skipped image: downSyndrome/down_10.jpg (No features detected)
# Skipped image: downSyndrome/down_1004.jpg (No features detected)
# Skipped image: downSyndrome/down_1005.jpg (No features detected)
# Skipped image: downSyndrome/down_101.jpg (No features detected)
# Skipped image: downSyndrome/down_1010.jpg (No features detected)
# Skipped image: downSyndrome/down_1013.jpg (No features detected)
# Skipped image: downSyndrome/down_1014.jpg (No features detected)
# Skipped image: downSyndrome/down_1019.jpg (No features detected)
# Skipped image: downSyndrome/down_1020.jpg (No features detected)
# Skipped image: downSyndrome/down_1030.jpg (No features detected)
# Skipped image: downSyndrome/down_1031.jpg (No features detected)
# Skipped image: downSyndrome/down_1032.jpg (No features detected)
# Skipped image: downSyndrome/down_1035.jpg (No features detected)
# Skipped image: downSyndrome/down_1039.jpg (No features detected)
# Skipped image: downSyndrome/down_1040.jpg (No features detected)
# Skipped image: downSyndrome/down_1043.jpg (No features detected)
# Skipped image: downSyndrome/down_1047.jpg (No features detected)
# Skipped image: downSyndrome/down_1055.jpg (No features detected)
# Skipped image: downSyndrome/down_1056.jpg (No features detected)
# Skipped image: downSyndrome/down_1057.jpg (No features detected)
# Skipped image: downSyndrome/down_1059.jpg (No features detected)
# Skipped image: downSyndrome/down_1062.jpg (No features detected)
# Skipped image: downSyndrome/down_1064.jpg (No features detected)
# Skipped image: downSyndrome/down_1066.jpg (No features detected)
# Skipped image: downSyndrome/down_1071.jpg (No features detected)
# Skipped image: downSyndrome/down_1075.jpg (No features detected)
# Skipped image: downSyndrome/down_1077.jpg (No features detected)
# Skipped image: downSyndrome/down_1078.jpg (No features detected)
# Skipped image: downSyndrome/down_1079.jpg (No features detected)
# Skipped image: downSyndrome/down_108.jpg (No features detected)
# Skipped image: downSyndrome/down_1081.jpg (No features detected)
# Skipped image: downSyndrome/down_1082.jpg (No features detected)
# Skipped image: downSyndrome/down_1088.jpg (No features detected)
# Skipped image: downSyndrome/down_109.jpg (No features detected)
# Skipped image: downSyndrome/down_1090.jpg (No features detected)
# Skipped image: downSyndrome/down_1092.jpg (No features detected)
# Skipped image: downSyndrome/down_1094.jpg (No features detected)
# Skipped image: downSyndrome/down_1098.jpg (No features detected)
# Skipped image: downSyndrome/down_11.jpg (No features detected)
# Skipped image: downSyndrome/down_110.jpg (No features detected)
# Skipped image: downSyndrome/down_1102.jpg (No features detected)
# Skipped image: downSyndrome/down_1108.jpg (No features detected)
# Skipped image: downSyndrome/down_111.jpg (No features detected)
# Skipped image: downSyndrome/down_1110.jpg (No features detected)
# Skipped image: downSyndrome/down_1111.jpg (No features detected)
# Skipped image: downSyndrome/down_1113.jpg (No features detected)
# Skipped image: downSyndrome/down_1114.jpg (No features detected)
# Skipped image: downSyndrome/down_1115.jpg (No features detected)
# Skipped image: downSyndrome/down_112.jpg (No features detected)
# Skipped image: downSyndrome/down_1123.jpg (No features detected)
# Skipped image: downSyndrome/down_1124.jpg (No features detected)
# Skipped image: downSyndrome/down_1127.jpg (No features detected)
# Skipped image: downSyndrome/down_1129.jpg (No features detected)
# Skipped image: downSyndrome/down_1130.jpg (No features detected)
# Skipped image: downSyndrome/down_1133.jpg (No features detected)
# Skipped image: downSyndrome/down_1135.jpg (No features detected)
# Skipped image: downSyndrome/down_1141.jpg (No features detected)
# Skipped image: downSyndrome/down_1143.jpg (No features detected)
# Skipped image: downSyndrome/down_1146.jpg (No features detected)
# Skipped image: downSyndrome/down_115.jpg (No features detected)
# Skipped image: downSyndrome/down_1150.jpg (No features detected)
# Skipped image: downSyndrome/down_116.jpg (No features detected)
# Skipped image: downSyndrome/down_1161.jpg (No features detected)
# Skipped image: downSyndrome/down_1163.jpg (No features detected)
# Skipped image: downSyndrome/down_1165.jpg (No features detected)
# Skipped image: downSyndrome/down_1166.jpg (No features detected)
# Skipped image: downSyndrome/down_1168.jpg (No features detected)
# Skipped image: downSyndrome/down_1169.jpg (No features detected)
# Skipped image: downSyndrome/down_1170.jpg (No features detected)
# Skipped image: downSyndrome/down_1173.jpg (No features detected)
# Skipped image: downSyndrome/down_1174.jpg (No features detected)
# Skipped image: downSyndrome/down_1181.jpg (No features detected)
# Skipped image: downSyndrome/down_1182.jpg (No features detected)
# Skipped image: downSyndrome/down_1183.jpg (No features detected)
# Skipped image: downSyndrome/down_1184.jpg (No features detected)
# Skipped image: downSyndrome/down_1185.jpg (No features detected)
# Skipped image: downSyndrome/down_1188.jpg (No features detected)
# Skipped image: downSyndrome/down_1189.jpg (No features detected)
# Skipped image: downSyndrome/down_1190.jpg (No features detected)
# Skipped image: downSyndrome/down_1191.jpg (No features detected)
# Skipped image: downSyndrome/down_1192.jpg (No features detected)
# Skipped image: downSyndrome/down_1193.jpg (No features detected)
# Skipped image: downSyndrome/down_1194.jpg (No features detected)
# Skipped image: downSyndrome/down_1195.jpg (No features detected)
# Skipped image: downSyndrome/down_1196.jpg (No features detected)
# Skipped image: downSyndrome/down_1198.jpg (No features detected)
# Skipped image: downSyndrome/down_120.jpg (No features detected)
# Skipped image: downSyndrome/down_1203.jpg (No features detected)
# Skipped image: downSyndrome/down_1205.jpg (No features detected)
# Skipped image: downSyndrome/down_1208.jpg (No features detected)
# Skipped image: downSyndrome/down_1210.jpg (No features detected)
# Skipped image: downSyndrome/down_1211.jpg (No features detected)
# Skipped image: downSyndrome/down_1216.jpg (No features detected)
# Skipped image: downSyndrome/down_1221.jpg (No features detected)
# Skipped image: downSyndrome/down_1223.jpg (No features detected)
# Skipped image: downSyndrome/down_1224.jpg (No features detected)
# Skipped image: downSyndrome/down_1227.jpg (No features detected)
# Skipped image: downSyndrome/down_1228.jpg (No features detected)
# Skipped image: downSyndrome/down_1230.jpg (No features detected)
# Skipped image: downSyndrome/down_1231.jpg (No features detected)
# Skipped image: downSyndrome/down_1232.jpg (No features detected)
# Skipped image: downSyndrome/down_1233.jpg (No features detected)
# Skipped image: downSyndrome/down_1238.jpg (No features detected)
# Skipped image: downSyndrome/down_1239.jpg (No features detected)
# Skipped image: downSyndrome/down_1240.jpg (No features detected)
# Skipped image: downSyndrome/down_1241.jpg (No features detected)
# Skipped image: downSyndrome/down_1245.jpg (No features detected)
# Skipped image: downSyndrome/down_1247.jpg (No features detected)
# Skipped image: downSyndrome/down_1248.jpg (No features detected)
# Skipped image: downSyndrome/down_1249.jpg (No features detected)
# Skipped image: downSyndrome/down_1253.jpg (No features detected)
# Skipped image: downSyndrome/down_1255.jpg (No features detected)
# Skipped image: downSyndrome/down_1257.jpg (No features detected)
# Skipped image: downSyndrome/down_1262.jpg (No features detected)
# Skipped image: downSyndrome/down_1263.jpg (No features detected)
# Skipped image: downSyndrome/down_1270.jpg (No features detected)
# Skipped image: downSyndrome/down_1271.jpg (No features detected)
# Skipped image: downSyndrome/down_1275.jpg (No features detected)
# Skipped image: downSyndrome/down_1278.jpg (No features detected)
# Skipped image: downSyndrome/down_1279.jpg (No features detected)
# Skipped image: downSyndrome/down_1283.jpg (No features detected)
# Skipped image: downSyndrome/down_1284.jpg (No features detected)
# Skipped image: downSyndrome/down_1286.jpg (No features detected)
# Skipped image: downSyndrome/down_1295.jpg (No features detected)
# Skipped image: downSyndrome/down_1297.jpg (No features detected)
# Skipped image: downSyndrome/down_1299.jpg (No features detected)
# Skipped image: downSyndrome/down_13.jpg (No features detected)
# Skipped image: downSyndrome/down_1300.jpg (No features detected)
# Skipped image: downSyndrome/down_1301.jpg (No features detected)
# Skipped image: downSyndrome/down_1303.jpg (No features detected)
# Skipped image: downSyndrome/down_1306.jpg (No features detected)
# Skipped image: downSyndrome/down_1310.jpg (No features detected)
# Skipped image: downSyndrome/down_1311.jpg (No features detected)
# Skipped image: downSyndrome/down_1312.jpg (No features detected)
# Skipped image: downSyndrome/down_1314.jpg (No features detected)
# Skipped image: downSyndrome/down_1315.jpg (No features detected)
# Skipped image: downSyndrome/down_1324.jpg (No features detected)
# Skipped image: downSyndrome/down_1325.jpg (No features detected)
# Skipped image: downSyndrome/down_1327.jpg (No features detected)
# Skipped image: downSyndrome/down_1332.jpg (No features detected)
# Skipped image: downSyndrome/down_1333.jpg (No features detected)
# Skipped image: downSyndrome/down_1336.jpg (No features detected)
# Skipped image: downSyndrome/down_1338.jpg (No features detected)
# Skipped image: downSyndrome/down_1339.jpg (No features detected)
# Skipped image: downSyndrome/down_1340.jpg (No features detected)
# Skipped image: downSyndrome/down_1341.jpg (No features detected)
# Skipped image: downSyndrome/down_1342.jpg (No features detected)
# Skipped image: downSyndrome/down_1344.jpg (No features detected)
# Skipped image: downSyndrome/down_1346.jpg (No features detected)
# Skipped image: downSyndrome/down_1347.jpg (No features detected)
# Skipped image: downSyndrome/down_1352.jpg (No features detected)
# Skipped image: downSyndrome/down_1353.jpg (No features detected)
# Skipped image: downSyndrome/down_1355.jpg (No features detected)
# Skipped image: downSyndrome/down_136.jpg (No features detected)
# Skipped image: downSyndrome/down_1360.jpg (No features detected)
# Skipped image: downSyndrome/down_1361.jpg (No features detected)
# Skipped image: downSyndrome/down_1362.jpg (No features detected)
# Skipped image: downSyndrome/down_1363.jpg (No features detected)
# Skipped image: downSyndrome/down_1365.jpg (No features detected)
# Skipped image: downSyndrome/down_1366.jpg (No features detected)
# Skipped image: downSyndrome/down_1367.jpg (No features detected)
# Skipped image: downSyndrome/down_1369.jpg (No features detected)
# Skipped image: downSyndrome/down_137.jpg (No features detected)
# Skipped image: downSyndrome/down_1373.jpg (No features detected)
# Skipped image: downSyndrome/down_1379.jpg (No features detected)
# Skipped image: downSyndrome/down_138.jpg (No features detected)
# Skipped image: downSyndrome/down_1380.jpg (No features detected)
# Skipped image: downSyndrome/down_1381.jpg (No features detected)
# Skipped image: downSyndrome/down_1383.jpg (No features detected)
# Skipped image: downSyndrome/down_1384.jpg (No features detected)
# Skipped image: downSyndrome/down_1385.jpg (No features detected)
# Skipped image: downSyndrome/down_1386.jpg (No features detected)
# Skipped image: downSyndrome/down_1395.jpg (No features detected)
# Skipped image: downSyndrome/down_1396.jpg (No features detected)
# Skipped image: downSyndrome/down_1398.jpg (No features detected)
# Skipped image: downSyndrome/down_1401.jpg (No features detected)
# Skipped image: downSyndrome/down_1402.jpg (No features detected)
# Skipped image: downSyndrome/down_1405.jpg (No features detected)
# Skipped image: downSyndrome/down_1407.jpg (No features detected)
# Skipped image: downSyndrome/down_1408.jpg (No features detected)
# Skipped image: downSyndrome/down_1409.jpg (No features detected)
# Skipped image: downSyndrome/down_1410.jpg (No features detected)
# Skipped image: downSyndrome/down_1414.jpg (No features detected)
# Skipped image: downSyndrome/down_1417.jpg (No features detected)
# Skipped image: downSyndrome/down_1418.jpg (No features detected)
# Skipped image: downSyndrome/down_1419.jpg (No features detected)
# Skipped image: downSyndrome/down_1420.jpg (No features detected)
# Skipped image: downSyndrome/down_1423.jpg (No features detected)
# Skipped image: downSyndrome/down_1424.jpg (No features detected)
# Skipped image: downSyndrome/down_1425.jpg (No features detected)
# Skipped image: downSyndrome/down_1427.jpg (No features detected)
# Skipped image: downSyndrome/down_1428.jpg (No features detected)
# Skipped image: downSyndrome/down_1433.jpg (No features detected)
# Skipped image: downSyndrome/down_1435.jpg (No features detected)
# Skipped image: downSyndrome/down_144.jpg (No features detected)
# Skipped image: downSyndrome/down_1441.jpg (No features detected)
# Skipped image: downSyndrome/down_1442.jpg (No features detected)
# Skipped image: downSyndrome/down_1443.jpg (No features detected)
# Skipped image: downSyndrome/down_1444.jpg (No features detected)
# Skipped image: downSyndrome/down_1446.jpg (No features detected)
# Skipped image: downSyndrome/down_1448.jpg (No features detected)
# Skipped image: downSyndrome/down_1451.jpg (No features detected)
# Skipped image: downSyndrome/down_1452.jpg (No features detected)
# Skipped image: downSyndrome/down_1453.jpg (No features detected)
# Skipped image: downSyndrome/down_1454.jpg (No features detected)
# Skipped image: downSyndrome/down_1455.jpg (No features detected)
# Skipped image: downSyndrome/down_1456.jpg (No features detected)
# Skipped image: downSyndrome/down_1458.jpg (No features detected)
# Skipped image: downSyndrome/down_1459.jpg (No features detected)
# Skipped image: downSyndrome/down_1462.jpg (No features detected)
# Skipped image: downSyndrome/down_1463.jpg (No features detected)
# Skipped image: downSyndrome/down_1464.jpg (No features detected)
# Skipped image: downSyndrome/down_1465.jpg (No features detected)
# Skipped image: downSyndrome/down_1466.jpg (No features detected)
# Skipped image: downSyndrome/down_1467.jpg (No features detected)
# Skipped image: downSyndrome/down_1468.jpg (No features detected)
# Skipped image: downSyndrome/down_1469.jpg (No features detected)
# Skipped image: downSyndrome/down_1471.jpg (No features detected)
# Skipped image: downSyndrome/down_1473.jpg (No features detected)
# Skipped image: downSyndrome/down_1477.jpg (No features detected)
# Skipped image: downSyndrome/down_1478.jpg (No features detected)
# Skipped image: downSyndrome/down_1480.jpg (No features detected)
# Skipped image: downSyndrome/down_1481.jpg (No features detected)
# Skipped image: downSyndrome/down_1482.jpg (No features detected)
# Skipped image: downSyndrome/down_149.jpg (No features detected)
# Skipped image: downSyndrome/down_1491.jpg (No features detected)
# Skipped image: downSyndrome/down_1493.jpg (No features detected)
# Skipped image: downSyndrome/down_1495.jpg (No features detected)
# Skipped image: downSyndrome/down_15.jpg (No features detected)
# Skipped image: downSyndrome/down_1500.jpg (No features detected)
# Skipped image: downSyndrome/down_1503.jpg (No features detected)
# Skipped image: downSyndrome/down_1504.jpg (No features detected)
# Skipped image: downSyndrome/down_1505.jpg (No features detected)
# Skipped image: downSyndrome/down_1507.jpg (No features detected)
# Skipped image: downSyndrome/down_151.jpg (No features detected)
# Skipped image: downSyndrome/down_1516.jpg (No features detected)
# Skipped image: downSyndrome/down_1517.jpg (No features detected)
# Skipped image: downSyndrome/down_1519.jpg (No features detected)
# Skipped image: downSyndrome/down_152.jpg (No features detected)
# Skipped image: downSyndrome/down_1520.jpg (No features detected)
# Skipped image: downSyndrome/down_1521.jpg (No features detected)
# Skipped image: downSyndrome/down_1522.jpg (No features detected)
# Skipped image: downSyndrome/down_1523.jpg (No features detected)
# Skipped image: downSyndrome/down_1526.jpg (No features detected)
# Skipped image: downSyndrome/down_153.jpg (No features detected)
# Skipped image: downSyndrome/down_155.jpg (No features detected)
# Skipped image: downSyndrome/down_157.jpg (No features detected)
# Skipped image: downSyndrome/down_16.jpg (No features detected)
# Skipped image: downSyndrome/down_163.jpg (No features detected)
# Skipped image: downSyndrome/down_165.jpg (No features detected)
# Skipped image: downSyndrome/down_166.jpg (No features detected)
# Skipped image: downSyndrome/down_167.jpg (No features detected)
# Skipped image: downSyndrome/down_169.jpg (No features detected)
# Skipped image: downSyndrome/down_17.jpg (No features detected)
# Skipped image: downSyndrome/down_171.jpg (No features detected)
# Skipped image: downSyndrome/down_173.jpg (No features detected)
# Skipped image: downSyndrome/down_175.jpg (No features detected)
# Skipped image: downSyndrome/down_182.jpg (No features detected)
# Skipped image: downSyndrome/down_184.jpg (No features detected)
# Skipped image: downSyndrome/down_185.jpg (No features detected)
# Skipped image: downSyndrome/down_186.jpg (No features detected)
# Skipped image: downSyndrome/down_188.jpg (No features detected)
# Skipped image: downSyndrome/down_189.jpg (No features detected)
# Skipped image: downSyndrome/down_19.jpg (No features detected)
# Skipped image: downSyndrome/down_191.jpg (No features detected)
# Skipped image: downSyndrome/down_192.jpg (No features detected)
# Skipped image: downSyndrome/down_196.jpg (No features detected)
# Skipped image: downSyndrome/down_197.jpg (No features detected)
# Skipped image: downSyndrome/down_199.jpg (No features detected)
# Skipped image: downSyndrome/down_2.jpg (No features detected)
# Skipped image: downSyndrome/down_20.png (No features detected)
# Skipped image: downSyndrome/down_201.jpg (No features detected)
# Skipped image: downSyndrome/down_202.jpg (No features detected)
# Skipped image: downSyndrome/down_207.jpg (No features detected)
# Skipped image: downSyndrome/down_208.jpg (No features detected)
# Skipped image: downSyndrome/down_209.jpg (No features detected)
# Skipped image: downSyndrome/down_210.jpg (No features detected)
# Skipped image: downSyndrome/down_211.jpg (No features detected)
# Skipped image: downSyndrome/down_213.jpg (No features detected)
# Skipped image: downSyndrome/down_214.jpg (No features detected)
# Skipped image: downSyndrome/down_215.jpg (No features detected)
# Skipped image: downSyndrome/down_216.jpg (No features detected)
# Skipped image: downSyndrome/down_217.jpg (No features detected)
# Skipped image: downSyndrome/down_220.jpg (No features detected)
# Skipped image: downSyndrome/down_222.jpg (No features detected)
# Skipped image: downSyndrome/down_224.jpg (No features detected)
# Skipped image: downSyndrome/down_226.jpg (No features detected)
# Skipped image: downSyndrome/down_227.jpg (No features detected)
# Skipped image: downSyndrome/down_229.jpg (No features detected)
# Skipped image: downSyndrome/down_23.png (No features detected)
# Skipped image: downSyndrome/down_233.jpg (No features detected)
# Skipped image: downSyndrome/down_240.jpg (No features detected)
# Skipped image: downSyndrome/down_242.jpg (No features detected)
# Skipped image: downSyndrome/down_244.jpg (No features detected)
# Skipped image: downSyndrome/down_245.jpg (No features detected)
# Skipped image: downSyndrome/down_246.jpg (No features detected)
# Skipped image: downSyndrome/down_247.jpg (No features detected)
# Skipped image: downSyndrome/down_249.jpg (No features detected)
# Skipped image: downSyndrome/down_25.jpg (No features detected)
# Skipped image: downSyndrome/down_252.jpg (No features detected)
# Skipped image: downSyndrome/down_257.jpg (No features detected)
# Skipped image: downSyndrome/down_261.jpg (No features detected)
# Skipped image: downSyndrome/down_263.jpg (No features detected)
# Skipped image: downSyndrome/down_264.jpg (No features detected)
# Skipped image: downSyndrome/down_265.jpg (No features detected)
# Skipped image: downSyndrome/down_266.jpg (No features detected)
# Skipped image: downSyndrome/down_267.jpg (No features detected)
# Skipped image: downSyndrome/down_268.jpg (No features detected)
# Skipped image: downSyndrome/down_269.jpg (No features detected)
# Skipped image: downSyndrome/down_270.jpg (No features detected)
# Skipped image: downSyndrome/down_271.jpg (No features detected)
# Skipped image: downSyndrome/down_273.jpg (No features detected)
# Skipped image: downSyndrome/down_274.jpg (No features detected)
# Skipped image: downSyndrome/down_279.jpg (No features detected)
# Skipped image: downSyndrome/down_283.jpg (No features detected)
# Skipped image: downSyndrome/down_286.jpg (No features detected)
# Skipped image: downSyndrome/down_29.jpg (No features detected)
# Skipped image: downSyndrome/down_292.jpg (No features detected)
# Skipped image: downSyndrome/down_295.jpg (No features detected)
# Skipped image: downSyndrome/down_297.jpg (No features detected)
# Skipped image: downSyndrome/down_308.jpg (No features detected)
# Skipped image: downSyndrome/down_31.png (No features detected)
# Skipped image: downSyndrome/down_310.jpg (No features detected)
# Skipped image: downSyndrome/down_313.jpg (No features detected)
# Skipped image: downSyndrome/down_32.jpg (No features detected)
# Skipped image: downSyndrome/down_320.jpg (No features detected)
# Skipped image: downSyndrome/down_323.jpg (No features detected)
# Skipped image: downSyndrome/down_324.jpg (No features detected)
# Skipped image: downSyndrome/down_327.jpg (No features detected)
# Skipped image: downSyndrome/down_329.jpg (No features detected)
# Skipped image: downSyndrome/down_33.jpg (No features detected)
# Skipped image: downSyndrome/down_330.jpg (No features detected)
# Skipped image: downSyndrome/down_332.jpg (No features detected)
# Skipped image: downSyndrome/down_333.jpg (No features detected)
# Skipped image: downSyndrome/down_334.jpg (No features detected)
# Skipped image: downSyndrome/down_338.jpg (No features detected)
# Skipped image: downSyndrome/down_342.jpg (No features detected)
# Skipped image: downSyndrome/down_343.jpg (No features detected)
# Skipped image: downSyndrome/down_348.jpg (No features detected)
# Skipped image: downSyndrome/down_349.jpg (No features detected)
# Skipped image: downSyndrome/down_351.jpg (No features detected)
# Skipped image: downSyndrome/down_355.jpg (No features detected)
# Skipped image: downSyndrome/down_357.jpg (No features detected)
# Skipped image: downSyndrome/down_359.jpg (No features detected)
# Skipped image: downSyndrome/down_36.jpg (No features detected)
# Skipped image: downSyndrome/down_361.jpg (No features detected)
# Skipped image: downSyndrome/down_362.jpg (No features detected)
# Skipped image: downSyndrome/down_363.jpg (No features detected)
# Skipped image: downSyndrome/down_365.jpg (No features detected)
# Skipped image: downSyndrome/down_366.jpg (No features detected)
# Skipped image: downSyndrome/down_367.jpg (No features detected)
# Skipped image: downSyndrome/down_369.jpg (No features detected)
# Skipped image: downSyndrome/down_374.jpg (No features detected)
# Skipped image: downSyndrome/down_375.jpg (No features detected)
# Skipped image: downSyndrome/down_388.jpg (No features detected)
# Skipped image: downSyndrome/down_39.jpg (No features detected)
# Skipped image: downSyndrome/down_390.jpg (No features detected)
# Skipped image: downSyndrome/down_391.jpg (No features detected)
# Skipped image: downSyndrome/down_394.jpg (No features detected)
# Skipped image: downSyndrome/down_397.jpg (No features detected)
# Skipped image: downSyndrome/down_398.jpg (No features detected)
# Skipped image: downSyndrome/down_405.jpg (No features detected)
# Skipped image: downSyndrome/down_406.jpg (No features detected)
# Skipped image: downSyndrome/down_407.jpg (No features detected)
# Skipped image: downSyndrome/down_408.jpg (No features detected)
# Skipped image: downSyndrome/down_409.jpg (No features detected)
# Skipped image: downSyndrome/down_41.jpg (No features detected)
# Skipped image: downSyndrome/down_410.jpg (No features detected)
# Skipped image: downSyndrome/down_412.jpg (No features detected)
# Skipped image: downSyndrome/down_413.jpg (No features detected)
# Skipped image: downSyndrome/down_414.jpg (No features detected)
# Skipped image: downSyndrome/down_416.jpg (No features detected)
# Skipped image: downSyndrome/down_419.jpg (No features detected)
# Skipped image: downSyndrome/down_42.png (No features detected)
# Skipped image: downSyndrome/down_422.jpg (No features detected)
# Skipped image: downSyndrome/down_425.jpg (No features detected)
# Skipped image: downSyndrome/down_427.jpg (No features detected)
# Skipped image: downSyndrome/down_429.jpg (No features detected)
# Skipped image: downSyndrome/down_43.png (No features detected)
# Skipped image: downSyndrome/down_434.jpg (No features detected)
# Skipped image: downSyndrome/down_437.jpg (No features detected)
# Skipped image: downSyndrome/down_438.jpg (No features detected)
# Skipped image: downSyndrome/down_439.jpg (No features detected)
# Skipped image: downSyndrome/down_440.jpg (No features detected)
# Skipped image: downSyndrome/down_441.jpg (No features detected)
# Skipped image: downSyndrome/down_442.jpg (No features detected)
# Skipped image: downSyndrome/down_443.jpg (No features detected)
# Skipped image: downSyndrome/down_446.jpg (No features detected)
# Skipped image: downSyndrome/down_449.jpg (No features detected)
# Skipped image: downSyndrome/down_450.jpg (No features detected)
# Skipped image: downSyndrome/down_455.jpg (No features detected)
# Skipped image: downSyndrome/down_458.jpg (No features detected)
# Skipped image: downSyndrome/down_466.jpg (No features detected)
# Skipped image: downSyndrome/down_469.jpg (No features detected)
# Skipped image: downSyndrome/down_472.jpg (No features detected)
# Skipped image: downSyndrome/down_477.jpg (No features detected)
# Skipped image: downSyndrome/down_48.jpg (No features detected)
# Skipped image: downSyndrome/down_497.jpg (No features detected)
# Skipped image: downSyndrome/down_499.jpg (No features detected)
# Skipped image: downSyndrome/down_50.jpg (No features detected)
# Skipped image: downSyndrome/down_500.jpg (No features detected)
# Skipped image: downSyndrome/down_504.jpg (No features detected)
# Skipped image: downSyndrome/down_506.jpg (No features detected)
# Skipped image: downSyndrome/down_508.jpg (No features detected)
# Skipped image: downSyndrome/down_513.jpg (No features detected)
# Skipped image: downSyndrome/down_514.jpg (No features detected)
# Skipped image: downSyndrome/down_516.jpg (No features detected)
# Skipped image: downSyndrome/down_517.jpg (No features detected)
# Skipped image: downSyndrome/down_518.jpg (No features detected)
# Skipped image: downSyndrome/down_524.jpg (No features detected)
# Skipped image: downSyndrome/down_525.jpg (No features detected)
# Skipped image: downSyndrome/down_526.jpg (No features detected)
# Skipped image: downSyndrome/down_534.jpg (No features detected)
# Skipped image: downSyndrome/down_535.jpg (No features detected)
# Skipped image: downSyndrome/down_536.jpg (No features detected)
# Skipped image: downSyndrome/down_537.jpg (No features detected)
# Skipped image: downSyndrome/down_538.jpg (No features detected)
# Skipped image: downSyndrome/down_54.jpg (No features detected)
# Skipped image: downSyndrome/down_541.jpg (No features detected)
# Skipped image: downSyndrome/down_542.jpg (No features detected)
# Skipped image: downSyndrome/down_545.jpg (No features detected)
# Skipped image: downSyndrome/down_546.jpg (No features detected)
# Skipped image: downSyndrome/down_549.jpg (No features detected)
# Skipped image: downSyndrome/down_55.jpg (No features detected)
# Skipped image: downSyndrome/down_553.jpg (No features detected)
# Skipped image: downSyndrome/down_554.jpg (No features detected)
# Skipped image: downSyndrome/down_557.jpg (No features detected)
# Skipped image: downSyndrome/down_561.jpg (No features detected)
# Skipped image: downSyndrome/down_563.jpg (No features detected)
# Skipped image: downSyndrome/down_565.jpg (No features detected)
# Skipped image: downSyndrome/down_567.jpg (No features detected)
# Skipped image: downSyndrome/down_568.jpg (No features detected)
# Skipped image: downSyndrome/down_569.jpg (No features detected)
# Skipped image: downSyndrome/down_572.jpg (No features detected)
# Skipped image: downSyndrome/down_575.jpg (No features detected)
# Skipped image: downSyndrome/down_577.jpg (No features detected)
# Skipped image: downSyndrome/down_578.jpg (No features detected)
# Skipped image: downSyndrome/down_58.jpg (No features detected)
# Skipped image: downSyndrome/down_582.jpg (No features detected)
# Skipped image: downSyndrome/down_583.jpg (No features detected)
# Skipped image: downSyndrome/down_589.jpg (No features detected)
# Skipped image: downSyndrome/down_59.jpg (No features detected)
# Skipped image: downSyndrome/down_593.jpg (No features detected)
# Skipped image: downSyndrome/down_596.jpg (No features detected)
# Skipped image: downSyndrome/down_6.jpg (No features detected)
# Skipped image: downSyndrome/down_60.jpg (No features detected)
# Skipped image: downSyndrome/down_601.jpg (No features detected)
# Skipped image: downSyndrome/down_608.jpg (No features detected)
# Skipped image: downSyndrome/down_609.jpg (No features detected)
# Skipped image: downSyndrome/down_61.jpg (No features detected)
# Skipped image: downSyndrome/down_610.jpg (No features detected)
# Skipped image: downSyndrome/down_611.jpg (No features detected)
# Skipped image: downSyndrome/down_615.jpg (No features detected)
# Skipped image: downSyndrome/down_616.jpg (No features detected)
# Skipped image: downSyndrome/down_618.jpg (No features detected)
# Skipped image: downSyndrome/down_62.jpg (No features detected)
# Skipped image: downSyndrome/down_622.jpg (No features detected)
# Skipped image: downSyndrome/down_623.jpg (No features detected)
# Skipped image: downSyndrome/down_624.jpg (No features detected)
# Skipped image: downSyndrome/down_625.jpg (No features detected)
# Skipped image: downSyndrome/down_626.jpg (No features detected)
# Skipped image: downSyndrome/down_627.jpg (No features detected)
# Skipped image: downSyndrome/down_628.jpg (No features detected)
# Skipped image: downSyndrome/down_629.jpg (No features detected)
# Skipped image: downSyndrome/down_63.jpg (No features detected)
# Skipped image: downSyndrome/down_633.jpg (No features detected)
# Skipped image: downSyndrome/down_636.jpg (No features detected)
# Skipped image: downSyndrome/down_638.jpg (No features detected)
# Skipped image: downSyndrome/down_639.jpg (No features detected)
# Skipped image: downSyndrome/down_64.jpg (No features detected)
# Skipped image: downSyndrome/down_644.jpg (No features detected)
# Skipped image: downSyndrome/down_645.jpg (No features detected)
# Skipped image: downSyndrome/down_647.jpg (No features detected)
# Skipped image: downSyndrome/down_648.jpg (No features detected)
# Skipped image: downSyndrome/down_649.jpg (No features detected)
# Skipped image: downSyndrome/down_65.jpg (No features detected)
# Skipped image: downSyndrome/down_652.jpg (No features detected)
# Skipped image: downSyndrome/down_653.jpg (No features detected)
# Skipped image: downSyndrome/down_654.jpg (No features detected)
# Skipped image: downSyndrome/down_655.jpg (No features detected)
# Skipped image: downSyndrome/down_656.jpg (No features detected)
# Skipped image: downSyndrome/down_658.jpg (No features detected)
# Skipped image: downSyndrome/down_659.jpg (No features detected)
# Skipped image: downSyndrome/down_66.jpg (No features detected)
# Skipped image: downSyndrome/down_661.jpg (No features detected)
# Skipped image: downSyndrome/down_662.jpg (No features detected)
# Skipped image: downSyndrome/down_663.jpg (No features detected)
# Skipped image: downSyndrome/down_665.jpg (No features detected)
# Skipped image: downSyndrome/down_666.jpg (No features detected)
# Skipped image: downSyndrome/down_67.png (No features detected)
# Skipped image: downSyndrome/down_670.jpg (No features detected)
# Skipped image: downSyndrome/down_673.jpg (No features detected)
# Skipped image: downSyndrome/down_677.jpg (No features detected)
# Skipped image: downSyndrome/down_678.jpg (No features detected)
# Skipped image: downSyndrome/down_68.jpg (No features detected)
# Skipped image: downSyndrome/down_683.jpg (No features detected)
# Skipped image: downSyndrome/down_684.jpg (No features detected)
# Skipped image: downSyndrome/down_687.jpg (No features detected)
# Skipped image: downSyndrome/down_69.jpg (No features detected)
# Skipped image: downSyndrome/down_690.jpg (No features detected)
# Skipped image: downSyndrome/down_692.jpg (No features detected)
# Skipped image: downSyndrome/down_694.jpg (No features detected)
# Skipped image: downSyndrome/down_7.jpg (No features detected)
# Skipped image: downSyndrome/down_70.jpg (No features detected)
# Skipped image: downSyndrome/down_702.jpg (No features detected)
# Skipped image: downSyndrome/down_705.jpg (No features detected)
# Skipped image: downSyndrome/down_706.jpg (No features detected)
# Skipped image: downSyndrome/down_708.jpg (No features detected)
# Skipped image: downSyndrome/down_712.jpg (No features detected)
# Skipped image: downSyndrome/down_714.jpg (No features detected)
# Skipped image: downSyndrome/down_715.jpg (No features detected)
# Skipped image: downSyndrome/down_716.jpg (No features detected)
# Skipped image: downSyndrome/down_717.jpg (No features detected)
# Skipped image: downSyndrome/down_718.jpg (No features detected)
# Skipped image: downSyndrome/down_719.jpg (No features detected)
# Skipped image: downSyndrome/down_72.jpg (No features detected)
# Skipped image: downSyndrome/down_720.jpg (No features detected)
# Skipped image: downSyndrome/down_722.jpg (No features detected)
# Skipped image: downSyndrome/down_725.jpg (No features detected)
# Skipped image: downSyndrome/down_727.jpg (No features detected)
# Skipped image: downSyndrome/down_728.jpg (No features detected)
# Skipped image: downSyndrome/down_73.jpg (No features detected)
# Skipped image: downSyndrome/down_733.jpg (No features detected)
# Skipped image: downSyndrome/down_734.jpg (No features detected)
# Skipped image: downSyndrome/down_735.jpg (No features detected)
# Skipped image: downSyndrome/down_736.jpg (No features detected)
# Skipped image: downSyndrome/down_738.jpg (No features detected)
# Skipped image: downSyndrome/down_739.jpg (No features detected)
# Skipped image: downSyndrome/down_740.jpg (No features detected)
# Skipped image: downSyndrome/down_741.jpg (No features detected)
# Skipped image: downSyndrome/down_745.jpg (No features detected)
# Skipped image: downSyndrome/down_746.jpg (No features detected)
# Skipped image: downSyndrome/down_748.jpg (No features detected)
# Skipped image: downSyndrome/down_750.jpg (No features detected)
# Skipped image: downSyndrome/down_752.jpg (No features detected)
# Skipped image: downSyndrome/down_756.jpg (No features detected)
# Skipped image: downSyndrome/down_757.jpg (No features detected)
# Skipped image: downSyndrome/down_759.jpg (No features detected)
# Skipped image: downSyndrome/down_760.jpg (No features detected)
# Skipped image: downSyndrome/down_761.jpg (No features detected)
# Skipped image: downSyndrome/down_762.jpg (No features detected)
# Skipped image: downSyndrome/down_765.jpg (No features detected)
# Skipped image: downSyndrome/down_767.jpg (No features detected)
# Skipped image: downSyndrome/down_768.jpg (No features detected)
# Skipped image: downSyndrome/down_77.jpg (No features detected)
# Skipped image: downSyndrome/down_773.jpg (No features detected)
# Skipped image: downSyndrome/down_774.jpg (No features detected)
# Skipped image: downSyndrome/down_775.jpg (No features detected)
# Skipped image: downSyndrome/down_777.jpg (No features detected)
# Skipped image: downSyndrome/down_78.jpg (No features detected)
# Skipped image: downSyndrome/down_781.jpg (No features detected)
# Skipped image: downSyndrome/down_782.jpg (No features detected)
# Skipped image: downSyndrome/down_785.jpg (No features detected)
# Skipped image: downSyndrome/down_79.jpg (No features detected)
# Skipped image: downSyndrome/down_790.jpg (No features detected)
# Skipped image: downSyndrome/down_792.jpg (No features detected)
# Skipped image: downSyndrome/down_797.jpg (No features detected)
# Skipped image: downSyndrome/down_801.jpg (No features detected)
# Skipped image: downSyndrome/down_804.jpg (No features detected)
# Skipped image: downSyndrome/down_807.jpg (No features detected)
# Skipped image: downSyndrome/down_808.jpg (No features detected)
# Skipped image: downSyndrome/down_81.jpg (No features detected)
# Skipped image: downSyndrome/down_811.jpg (No features detected)
# Skipped image: downSyndrome/down_815.jpg (No features detected)
# Skipped image: downSyndrome/down_817.jpg (No features detected)
# Skipped image: downSyndrome/down_818.jpg (No features detected)
# Skipped image: downSyndrome/down_819.jpg (No features detected)
# Skipped image: downSyndrome/down_820.jpg (No features detected)
# Skipped image: downSyndrome/down_825.jpg (No features detected)
# Skipped image: downSyndrome/down_826.jpg (No features detected)
# Skipped image: downSyndrome/down_830.jpg (No features detected)
# Skipped image: downSyndrome/down_831.jpg (No features detected)
# Skipped image: downSyndrome/down_832.jpg (No features detected)
# Skipped image: downSyndrome/down_833.jpg (No features detected)
# Skipped image: downSyndrome/down_834.jpg (No features detected)
# Skipped image: downSyndrome/down_837.jpg (No features detected)
# Skipped image: downSyndrome/down_838.jpg (No features detected)
# Skipped image: downSyndrome/down_839.jpg (No features detected)
# Skipped image: downSyndrome/down_841.jpg (No features detected)
# Skipped image: downSyndrome/down_842.jpg (No features detected)
# Skipped image: downSyndrome/down_844.jpg (No features detected)
# Skipped image: downSyndrome/down_845.jpg (No features detected)
# Skipped image: downSyndrome/down_846.jpg (No features detected)
# Skipped image: downSyndrome/down_847.jpg (No features detected)
# Skipped image: downSyndrome/down_848.jpg (No features detected)
# Skipped image: downSyndrome/down_85.jpg (No features detected)
# Skipped image: downSyndrome/down_852.jpg (No features detected)
# Skipped image: downSyndrome/down_854.jpg (No features detected)
# Skipped image: downSyndrome/down_859.jpg (No features detected)
# Skipped image: downSyndrome/down_86.jpg (No features detected)
# Skipped image: downSyndrome/down_862.jpg (No features detected)
# Skipped image: downSyndrome/down_863.jpg (No features detected)
# Skipped image: downSyndrome/down_869.jpg (No features detected)
# Skipped image: downSyndrome/down_870.jpg (No features detected)
# Skipped image: downSyndrome/down_876.jpg (No features detected)
# Skipped image: downSyndrome/down_877.jpg (No features detected)
# Skipped image: downSyndrome/down_879.jpg (No features detected)
# Skipped image: downSyndrome/down_880.jpg (No features detected)
# Skipped image: downSyndrome/down_881.jpg (No features detected)
# Skipped image: downSyndrome/down_882.jpg (No features detected)
# Skipped image: downSyndrome/down_884.jpg (No features detected)
# Skipped image: downSyndrome/down_885.jpg (No features detected)
# Skipped image: downSyndrome/down_887.jpg (No features detected)
# Skipped image: downSyndrome/down_888.jpg (No features detected)
# Skipped image: downSyndrome/down_89.jpg (No features detected)
# Skipped image: downSyndrome/down_902.jpg (No features detected)
# Skipped image: downSyndrome/down_905.jpg (No features detected)
# Skipped image: downSyndrome/down_906.jpg (No features detected)
# Skipped image: downSyndrome/down_907.jpg (No features detected)
# Skipped image: downSyndrome/down_913.jpg (No features detected)
# Skipped image: downSyndrome/down_915.jpg (No features detected)
# Skipped image: downSyndrome/down_917.jpg (No features detected)
# Skipped image: downSyndrome/down_918.jpg (No features detected)
# Skipped image: downSyndrome/down_919.jpg (No features detected)
# Skipped image: downSyndrome/down_92.png (No features detected)
# Skipped image: downSyndrome/down_920.jpg (No features detected)
# Skipped image: downSyndrome/down_921.jpg (No features detected)
# Skipped image: downSyndrome/down_923.jpg (No features detected)
# Skipped image: downSyndrome/down_928.jpg (No features detected)
# Skipped image: downSyndrome/down_929.jpg (No features detected)
# Skipped image: downSyndrome/down_930.jpg (No features detected)
# Skipped image: downSyndrome/down_931.jpg (No features detected)
# Skipped image: downSyndrome/down_932.jpg (No features detected)
# Skipped image: downSyndrome/down_933.jpg (No features detected)
# Skipped image: downSyndrome/down_940.jpg (No features detected)
# Skipped image: downSyndrome/down_942.jpg (No features detected)
# Skipped image: downSyndrome/down_948.jpg (No features detected)
# Skipped image: downSyndrome/down_95.jpg (No features detected)
# Skipped image: downSyndrome/down_950.jpg (No features detected)
# Skipped image: downSyndrome/down_951.jpg (No features detected)
# Skipped image: downSyndrome/down_957.jpg (No features detected)
# Skipped image: downSyndrome/down_958.jpg (No features detected)
# Skipped image: downSyndrome/down_96.jpg (No features detected)
# Skipped image: downSyndrome/down_960.jpg (No features detected)
# Skipped image: downSyndrome/down_962.jpg (No features detected)
# Skipped image: downSyndrome/down_965.jpg (No features detected)
# Skipped image: downSyndrome/down_968.jpg (No features detected)
# Skipped image: downSyndrome/down_969.jpg (No features detected)
# Skipped image: downSyndrome/down_972.jpg (No features detected)
# Skipped image: downSyndrome/down_975.jpg (No features detected)
# Skipped image: downSyndrome/down_976.jpg (No features detected)
# Skipped image: downSyndrome/down_978.jpg (No features detected)
# Skipped image: downSyndrome/down_980.jpg (No features detected)
# Skipped image: downSyndrome/down_981.jpg (No features detected)
# Skipped image: downSyndrome/down_985.jpg (No features detected)
# Skipped image: downSyndrome/down_986.jpg (No features detected)
# Skipped image: downSyndrome/down_992.jpg (No features detected)
# Skipped image: downSyndrome/down_994.jpg (No features detected)
# Skipped image: downSyndrome/down_995.jpg (No features detected)
# Skipped image: downSyndrome/down_996.jpg (No features detected)
# Skipped image: downSyndrome/down_997.jpg (No features detected)
# Skipped image: healty/healty_1000.jpg (No features detected)
# Skipped image: healty/healty_1001.jpg (No features detected)
# Skipped image: healty/healty_1002.jpg (No features detected)
# Skipped image: healty/healty_1003.jpg (No features detected)
# Skipped image: healty/healty_1004.jpg (No features detected)
# Skipped image: healty/healty_1005.jpg (No features detected)
# Skipped image: healty/healty_1006.jpg (No features detected)
# Skipped image: healty/healty_1007.jpg (No features detected)
# Skipped image: healty/healty_1009.jpg (No features detected)
# Skipped image: healty/healty_1011.jpg (No features detected)
# Skipped image: healty/healty_1014.jpg (No features detected)
# Skipped image: healty/healty_1015.jpg (No features detected)
# Skipped image: healty/healty_1016.jpg (No features detected)
# Skipped image: healty/healty_1017.jpg (No features detected)
# Skipped image: healty/healty_1019.jpg (No features detected)
# Skipped image: healty/healty_102.jpg (No features detected)
# Skipped image: healty/healty_1020.jpg (No features detected)
# Skipped image: healty/healty_1024.jpg (No features detected)
# Skipped image: healty/healty_1026.jpg (No features detected)
# Skipped image: healty/healty_1027.jpg (No features detected)
# Skipped image: healty/healty_1028.jpg (No features detected)
# Skipped image: healty/healty_103.jpg (No features detected)
# Skipped image: healty/healty_1030.jpg (No features detected)
# Skipped image: healty/healty_1031.jpg (No features detected)
# Skipped image: healty/healty_1033.jpg (No features detected)
# Skipped image: healty/healty_1034.jpg (No features detected)
# Skipped image: healty/healty_1036.jpg (No features detected)
# Skipped image: healty/healty_1037.jpg (No features detected)
# Skipped image: healty/healty_104.jpg (No features detected)
# Skipped image: healty/healty_1042.jpg (No features detected)
# Skipped image: healty/healty_1043.jpg (No features detected)
# Skipped image: healty/healty_1044.jpg (No features detected)
# Skipped image: healty/healty_1045.jpg (No features detected)
# Skipped image: healty/healty_1046.jpg (No features detected)
# Skipped image: healty/healty_1047.jpg (No features detected)
# Skipped image: healty/healty_1048.jpg (No features detected)
# Skipped image: healty/healty_1049.jpg (No features detected)
# Skipped image: healty/healty_105.jpg (No features detected)
# Skipped image: healty/healty_1050.jpg (No features detected)
# Skipped image: healty/healty_1051.jpg (No features detected)
# Skipped image: healty/healty_1052.jpg (No features detected)
# Skipped image: healty/healty_1053.jpg (No features detected)
# Skipped image: healty/healty_1054.jpg (No features detected)
# Skipped image: healty/healty_1055.jpg (No features detected)
# Skipped image: healty/healty_1056.jpg (No features detected)
# Skipped image: healty/healty_1057.jpg (No features detected)
# Skipped image: healty/healty_1059.jpg (No features detected)
# Skipped image: healty/healty_106.jpg (No features detected)
# Skipped image: healty/healty_1062.jpg (No features detected)
# Skipped image: healty/healty_1065.jpg (No features detected)
# Skipped image: healty/healty_1068.jpg (No features detected)
# Skipped image: healty/healty_1069.jpg (No features detected)
# Skipped image: healty/healty_107.jpg (No features detected)
# Skipped image: healty/healty_1070.jpg (No features detected)
# Skipped image: healty/healty_1079.jpg (No features detected)
# Skipped image: healty/healty_108.jpg (No features detected)
# Skipped image: healty/healty_1080.jpg (No features detected)
# Skipped image: healty/healty_1082.jpg (No features detected)
# Skipped image: healty/healty_1083.jpg (No features detected)
# Skipped image: healty/healty_1086.jpg (No features detected)
# Skipped image: healty/healty_1087.jpg (No features detected)
# Skipped image: healty/healty_1089.jpg (No features detected)
# Skipped image: healty/healty_1090.jpg (No features detected)
# Skipped image: healty/healty_1095.jpg (No features detected)
# Skipped image: healty/healty_1098.jpg (No features detected)
# Skipped image: healty/healty_1099.jpg (No features detected)
# Skipped image: healty/healty_1100.jpg (No features detected)
# Skipped image: healty/healty_1105.jpg (No features detected)
# Skipped image: healty/healty_1107.jpg (No features detected)
# Skipped image: healty/healty_1109.jpg (No features detected)
# Skipped image: healty/healty_1110.jpg (No features detected)
# Skipped image: healty/healty_1111.jpg (No features detected)
# Skipped image: healty/healty_1113.jpg (No features detected)
# Skipped image: healty/healty_1114.jpg (No features detected)
# Skipped image: healty/healty_1115.jpg (No features detected)
# Skipped image: healty/healty_1116.jpg (No features detected)
# Skipped image: healty/healty_1117.jpg (No features detected)
# Skipped image: healty/healty_1118.jpg (No features detected)
# Skipped image: healty/healty_112.jpg (No features detected)
# Skipped image: healty/healty_1123.jpg (No features detected)
# Skipped image: healty/healty_1125.jpg (No features detected)
# Skipped image: healty/healty_1126.jpg (No features detected)
# Skipped image: healty/healty_1127.jpg (No features detected)
# Skipped image: healty/healty_1128.jpg (No features detected)
# Skipped image: healty/healty_1129.jpg (No features detected)
# Skipped image: healty/healty_1132.jpg (No features detected)
# Skipped image: healty/healty_1135.jpg (No features detected)
# Skipped image: healty/healty_1137.jpg (No features detected)
# Skipped image: healty/healty_1138.jpg (No features detected)
# Skipped image: healty/healty_1139.jpg (No features detected)
# Skipped image: healty/healty_114.jpg (No features detected)
# Skipped image: healty/healty_1141.jpg (No features detected)
# Skipped image: healty/healty_1142.jpg (No features detected)
# Skipped image: healty/healty_1147.jpg (No features detected)
# Skipped image: healty/healty_1148.jpg (No features detected)
# Skipped image: healty/healty_115.jpg (No features detected)
# Skipped image: healty/healty_1157.jpg (No features detected)
# Skipped image: healty/healty_1158.jpg (No features detected)
# Skipped image: healty/healty_116.jpg (No features detected)
# Skipped image: healty/healty_1160.jpg (No features detected)
# Skipped image: healty/healty_1162.jpg (No features detected)
# ...
# Skipped image: healty/healty_377.jpg (No features detected)
# Skipped image: healty/healty_380.jpg (No features detected)
# Skipped image: healty/healty_383.jpg (No features detected)
# Skipped image: healty/healty_392.jpg (No features detected)
# Skipped image: healty/healty_395.jpg (No features detected)
# Skipped image: healty/healty_399.jpg (No features detected)
# Skipped image: healty/healty_405.jpg (No features detected)
# Skipped image: healty/healty_406.jpg (No features detected)
# Skipped image: healty/healty_410.jpg (No features detected)
# Skipped image: healty/healty_411.jpg (No features detected)
# Skipped image: healty/healty_412.jpg (No features detected)
# Skipped image: healty/healty_416.jpg (No features detected)
# Skipped image: healty/healty_417.jpg (No features detected)
# Skipped image: healty/healty_418.jpg (No features detected)
# Skipped image: healty/healty_42.jpg (No features detected)
# Skipped image: healty/healty_420.jpg (No features detected)
# Skipped image: healty/healty_422.jpg (No features detected)
# Skipped image: healty/healty_423.jpg (No features detected)
# Skipped image: healty/healty_426.jpg (No features detected)
# Skipped image: healty/healty_428.jpg (No features detected)
# Skipped image: healty/healty_429.jpg (No features detected)
# Skipped image: healty/healty_430.jpg (No features detected)
# Skipped image: healty/healty_431.jpg (No features detected)
# Skipped image: healty/healty_433.jpg (No features detected)
# Skipped image: healty/healty_435.jpg (No features detected)
# Skipped image: healty/healty_436.jpg (No features detected)
# Skipped image: healty/healty_438.jpg (No features detected)
# Skipped image: healty/healty_439.jpg (No features detected)
# Skipped image: healty/healty_440.jpg (No features detected)
# Skipped image: healty/healty_442.jpg (No features detected)
# Skipped image: healty/healty_443.jpg (No features detected)
# Skipped image: healty/healty_447.jpg (No features detected)
# Skipped image: healty/healty_451.jpg (No features detected)
# Skipped image: healty/healty_452.jpg (No features detected)
# Skipped image: healty/healty_454.jpg (No features detected)
# Skipped image: healty/healty_455.jpg (No features detected)
# Skipped image: healty/healty_456.jpg (No features detected)
# Skipped image: healty/healty_458.jpg (No features detected)
# Skipped image: healty/healty_459.jpg (No features detected)
# Skipped image: healty/healty_460.jpg (No features detected)
# Skipped image: healty/healty_462.jpg (No features detected)
# Skipped image: healty/healty_464.jpg (No features detected)
# Skipped image: healty/healty_467.jpg (No features detected)
# Skipped image: healty/healty_468.jpg (No features detected)
# Skipped image: healty/healty_47.jpg (No features detected)
# Skipped image: healty/healty_470.jpg (No features detected)
# Skipped image: healty/healty_473.jpg (No features detected)
# Skipped image: healty/healty_474.jpg (No features detected)
# Skipped image: healty/healty_475.jpg (No features detected)
# Skipped image: healty/healty_476.jpg (No features detected)
# Skipped image: healty/healty_477.jpg (No features detected)
# Skipped image: healty/healty_479.jpg (No features detected)
# Skipped image: healty/healty_48.jpg (No features detected)
# Skipped image: healty/healty_481.jpg (No features detected)
# Skipped image: healty/healty_485.jpg (No features detected)
# Skipped image: healty/healty_486.jpg (No features detected)
# Skipped image: healty/healty_487.jpg (No features detected)
# Skipped image: healty/healty_49.jpg (No features detected)
# Skipped image: healty/healty_490.jpg (No features detected)
# Skipped image: healty/healty_497.jpg (No features detected)
# Skipped image: healty/healty_5.jpg (No features detected)
# Skipped image: healty/healty_501.jpg (No features detected)
# Skipped image: healty/healty_502.jpg (No features detected)
# Skipped image: healty/healty_505.jpg (No features detected)
# Skipped image: healty/healty_506.jpg (No features detected)
# Skipped image: healty/healty_510.jpg (No features detected)
# Skipped image: healty/healty_511.jpg (No features detected)
# Skipped image: healty/healty_512.jpg (No features detected)
# Skipped image: healty/healty_513.jpg (No features detected)
# Skipped image: healty/healty_515.jpg (No features detected)
# Skipped image: healty/healty_518.jpg (No features detected)
# Skipped image: healty/healty_52.jpg (No features detected)
# Skipped image: healty/healty_522.jpg (No features detected)
# Skipped image: healty/healty_523.jpg (No features detected)
# Skipped image: healty/healty_526.jpg (No features detected)
# Skipped image: healty/healty_529.jpg (No features detected)
# Skipped image: healty/healty_530.jpg (No features detected)
# Skipped image: healty/healty_531.jpg (No features detected)
# Skipped image: healty/healty_536.jpg (No features detected)
# Skipped image: healty/healty_537.jpg (No features detected)
# Skipped image: healty/healty_539.jpg (No features detected)
# Skipped image: healty/healty_540.jpg (No features detected)
# Skipped image: healty/healty_541.jpg (No features detected)
# Skipped image: healty/healty_544.jpg (No features detected)
# Skipped image: healty/healty_545.jpg (No features detected)
# Skipped image: healty/healty_546.jpg (No features detected)
# Skipped image: healty/healty_547.jpg (No features detected)
# Skipped image: healty/healty_548.jpg (No features detected)
# Skipped image: healty/healty_549.jpg (No features detected)
# Skipped image: healty/healty_550.jpg (No features detected)
# Skipped image: healty/healty_551.jpg (No features detected)
# Skipped image: healty/healty_553.jpg (No features detected)
# Skipped image: healty/healty_555.jpg (No features detected)
# Skipped image: healty/healty_556.jpg (No features detected)
# Skipped image: healty/healty_558.jpg (No features detected)
# Skipped image: healty/healty_564.jpg (No features detected)
# Skipped image: healty/healty_565.jpg (No features detected)
# Skipped image: healty/healty_566.jpg (No features detected)
# Skipped image: healty/healty_567.jpg (No features detected)
# Skipped image: healty/healty_569.jpg (No features detected)
# Skipped image: healty/healty_570.jpg (No features detected)
# Skipped image: healty/healty_574.jpg (No features detected)
# Skipped image: healty/healty_579.jpg (No features detected)
# Skipped image: healty/healty_580.jpg (No features detected)
# Skipped image: healty/healty_581.jpg (No features detected)
# Skipped image: healty/healty_583.jpg (No features detected)
# Skipped image: healty/healty_587.jpg (No features detected)
# Skipped image: healty/healty_588.jpg (No features detected)
# Skipped image: healty/healty_590.jpg (No features detected)
# Skipped image: healty/healty_591.jpg (No features detected)
# Skipped image: healty/healty_592.jpg (No features detected)
# Skipped image: healty/healty_593.jpg (No features detected)
# Skipped image: healty/healty_594.jpg (No features detected)
# Skipped image: healty/healty_597.jpg (No features detected)
# Skipped image: healty/healty_598.jpg (No features detected)
# Skipped image: healty/healty_60.jpg (No features detected)
# Skipped image: healty/healty_601.jpg (No features detected)
# Skipped image: healty/healty_605.jpg (No features detected)
# Skipped image: healty/healty_607.jpg (No features detected)
# Skipped image: healty/healty_610.jpg (No features detected)
# Skipped image: healty/healty_615.jpg (No features detected)
# Skipped image: healty/healty_617.jpg (No features detected)
# Skipped image: healty/healty_619.jpg (No features detected)
# Skipped image: healty/healty_620.jpg (No features detected)
# Skipped image: healty/healty_621.jpg (No features detected)
# Skipped image: healty/healty_623.jpg (No features detected)
# Skipped image: healty/healty_625.jpg (No features detected)
# Skipped image: healty/healty_626.jpg (No features detected)
# Skipped image: healty/healty_628.jpg (No features detected)
# Skipped image: healty/healty_631.jpg (No features detected)
# Skipped image: healty/healty_632.jpg (No features detected)
# Skipped image: healty/healty_635.jpg (No features detected)
# Skipped image: healty/healty_637.jpg (No features detected)
# Skipped image: healty/healty_64.jpg (No features detected)
# Skipped image: healty/healty_646.jpg (No features detected)
# Skipped image: healty/healty_648.jpg (No features detected)
# Skipped image: healty/healty_649.jpg (No features detected)
# Skipped image: healty/healty_650.jpg (No features detected)
# Skipped image: healty/healty_651.jpg (No features detected)
# Skipped image: healty/healty_652.jpg (No features detected)
# Skipped image: healty/healty_655.jpg (No features detected)
# Skipped image: healty/healty_656.jpg (No features detected)
# Skipped image: healty/healty_657.jpg (No features detected)
# Skipped image: healty/healty_659.jpg (No features detected)
# Skipped image: healty/healty_660.jpg (No features detected)
# Skipped image: healty/healty_661.jpg (No features detected)
# Skipped image: healty/healty_667.jpg (No features detected)
# Skipped image: healty/healty_670.jpg (No features detected)
# Skipped image: healty/healty_674.jpg (No features detected)
# Skipped image: healty/healty_675.jpg (No features detected)
# Skipped image: healty/healty_676.jpg (No features detected)
# Skipped image: healty/healty_678.jpg (No features detected)
# Skipped image: healty/healty_680.jpg (No features detected)
# Skipped image: healty/healty_681.jpg (No features detected)
# Skipped image: healty/healty_682.jpg (No features detected)
# Skipped image: healty/healty_684.jpg (No features detected)
# Skipped image: healty/healty_687.jpg (No features detected)
# Skipped image: healty/healty_691.jpg (No features detected)
# Skipped image: healty/healty_702.jpg (No features detected)
# Skipped image: healty/healty_705.jpg (No features detected)
# Skipped image: healty/healty_707.jpg (No features detected)
# Skipped image: healty/healty_71.jpg (No features detected)
# Skipped image: healty/healty_710.jpg (No features detected)
# Skipped image: healty/healty_715.jpg (No features detected)
# Skipped image: healty/healty_716.jpg (No features detected)
# Skipped image: healty/healty_72.jpg (No features detected)
# Skipped image: healty/healty_722.jpg (No features detected)
# Skipped image: healty/healty_727.jpg (No features detected)
# Skipped image: healty/healty_728.jpg (No features detected)
# Skipped image: healty/healty_730.jpg (No features detected)
# Skipped image: healty/healty_732.jpg (No features detected)
# Skipped image: healty/healty_734.jpg (No features detected)
# Skipped image: healty/healty_735.jpg (No features detected)
# Skipped image: healty/healty_739.jpg (No features detected)
# Skipped image: healty/healty_741.jpg (No features detected)
# Skipped image: healty/healty_744.jpg (No features detected)
# Skipped image: healty/healty_745.jpg (No features detected)
# Skipped image: healty/healty_746.jpg (No features detected)
# Skipped image: healty/healty_747.jpg (No features detected)
# Skipped image: healty/healty_748.jpg (No features detected)
# Skipped image: healty/healty_749.jpg (No features detected)
# Skipped image: healty/healty_753.jpg (No features detected)
# Skipped image: healty/healty_754.jpg (No features detected)
# Skipped image: healty/healty_757.jpg (No features detected)
# Skipped image: healty/healty_758.jpg (No features detected)
# Skipped image: healty/healty_759.jpg (No features detected)
# Skipped image: healty/healty_760.jpg (No features detected)
# Skipped image: healty/healty_77.jpg (No features detected)
# Skipped image: healty/healty_770.jpg (No features detected)
# Skipped image: healty/healty_774.jpg (No features detected)
# Skipped image: healty/healty_776.jpg (No features detected)
# Skipped image: healty/healty_777.jpg (No features detected)
# Skipped image: healty/healty_778.jpg (No features detected)
# Skipped image: healty/healty_780.jpg (No features detected)
# Skipped image: healty/healty_783.jpg (No features detected)
# Skipped image: healty/healty_784.jpg (No features detected)
# Skipped image: healty/healty_785.jpg (No features detected)
# Skipped image: healty/healty_79.jpg (No features detected)
# Skipped image: healty/healty_798.jpg (No features detected)
# Skipped image: healty/healty_799.jpg (No features detected)
# Skipped image: healty/healty_844.jpg (No features detected)
# Skipped image: healty/healty_85.jpg (No features detected)
# Skipped image: healty/healty_858.jpg (No features detected)
# Skipped image: healty/healty_86.jpg (No features detected)
# Skipped image: healty/healty_87.jpg (No features detected)
# Skipped image: healty/healty_875.jpg (No features detected)
# Skipped image: healty/healty_88.jpg (No features detected)
# Skipped image: healty/healty_886.jpg (No features detected)
# Skipped image: healty/healty_89.jpg (No features detected)
# Skipped image: healty/healty_890.jpg (No features detected)
# Skipped image: healty/healty_895.jpg (No features detected)
# Skipped image: healty/healty_896.jpg (No features detected)
# Skipped image: healty/healty_897.jpg (No features detected)
# Skipped image: healty/healty_899.jpg (No features detected)
# Skipped image: healty/healty_9.jpg (No features detected)
# Skipped image: healty/healty_901.jpg (No features detected)
# Skipped image: healty/healty_903.jpg (No features detected)
# Skipped image: healty/healty_906.jpg (No features detected)
# Skipped image: healty/healty_909.jpg (No features detected)
# Skipped image: healty/healty_911.jpg (No features detected)
# Skipped image: healty/healty_914.jpg (No features detected)
# Skipped image: healty/healty_915.jpg (No features detected)
# Skipped image: healty/healty_917.jpg (No features detected)
# Skipped image: healty/healty_920.jpg (No features detected)
# Skipped image: healty/healty_923.jpg (No features detected)
# Skipped image: healty/healty_924.jpg (No features detected)
# Skipped image: healty/healty_925.jpg (No features detected)
# Skipped image: healty/healty_929.jpg (No features detected)
# Skipped image: healty/healty_93.jpg (No features detected)
# Skipped image: healty/healty_930.jpg (No features detected)
# Skipped image: healty/healty_932.jpg (No features detected)
# Skipped image: healty/healty_934.jpg (No features detected)
# Skipped image: healty/healty_935.jpg (No features detected)
# Skipped image: healty/healty_938.jpg (No features detected)
# Skipped image: healty/healty_939.jpg (No features detected)
# Skipped image: healty/healty_94.jpg (No features detected)
# Skipped image: healty/healty_941.jpg (No features detected)
# Skipped image: healty/healty_943.jpg (No features detected)
# Skipped image: healty/healty_944.jpg (No features detected)
# Skipped image: healty/healty_948.jpg (No features detected)
# Skipped image: healty/healty_949.jpg (No features detected)
# Skipped image: healty/healty_951.jpg (No features detected)
# Skipped image: healty/healty_952.jpg (No features detected)
# Skipped image: healty/healty_957.jpg (No features detected)
# Skipped image: healty/healty_958.jpg (No features detected)
# Skipped image: healty/healty_959.jpg (No features detected)
# Skipped image: healty/healty_961.jpg (No features detected)
# Skipped image: healty/healty_963.jpg (No features detected)
# Skipped image: healty/healty_965.jpg (No features detected)
# Skipped image: healty/healty_966.jpg (No features detected)
# Skipped image: healty/healty_968.jpg (No features detected)
# Skipped image: healty/healty_97.jpg (No features detected)
# Skipped image: healty/healty_972.jpg (No features detected)
# Skipped image: healty/healty_973.jpg (No features detected)
# Skipped image: healty/healty_974.jpg (No features detected)
# Skipped image: healty/healty_975.jpg (No features detected)
# Skipped image: healty/healty_977.jpg (No features detected)
# Skipped image: healty/healty_978.jpg (No features detected)
# Skipped image: healty/healty_979.jpg (No features detected)
# Skipped image: healty/healty_98.jpg (No features detected)
# Skipped image: healty/healty_984.jpg (No features detected)
# Skipped image: healty/healty_989.jpg (No features detected)
# Skipped image: healty/healty_992.jpg (No features detected)
# Skipped image: healty/healty_994.jpg (No features detected)
# Skipped image: healty/healty_995.jpg (No features detected)
# Skipped image: healty/healty_996.jpg (No features detected)
# Skipped image: healty/healty_997.jpg (No features detected)

# %%
# Convert to arrays
X = np.array(X)
y = np.array(y)

# Handle NaNs and scale features
X = np.nan_to_num(X)
scaler = StandardScaler()
X = scaler.fit_transform(X)

# # Dimensionality reduction
# pca = PCA(n_components=50)
# X = pca.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Train the model
model = SVC(C=0.8, kernel='rbf', gamma='scale', probability=True, class_weight='balanced')
start_time = time.time()
model.fit(X_train, y_train)
end_time = time.time()

training_time = end_time - start_time
print(f"Training Time: {training_time:.2f} seconds")
# Out:
# Training Time: 25.97 seconds

# %%
cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')
print(f"5-Fold Cross-Validation Accuracy: {np.mean(cv_scores):.2f}")

# Evaluate on the test set
y_pred_test = model.predict(X_test)
accuracy_test = accuracy_score(y_test, y_pred_test)
precision_test = precision_score(y_test, y_pred_test)
recall_test = recall_score(y_test, y_pred_test)
auc_test = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])

print(f"Test Accuracy: {accuracy_test:.2f}")
print(f"Test Precision: {precision_test:.2f}")
print(f"Test Recall: {recall_test:.2f}")
print(f"Test AUC: {auc_test:.2f}")
print("Test Classification Report:")
print(classification_report(y_test, y_pred_test))

# Evaluate on the training set
y_pred_train = model.predict(X_train)
accuracy_train = accuracy_score(y_train, y_pred_train)
precision_train = precision_score(y_train, y_pred_train)
recall_train = recall_score(y_train, y_pred_train)
auc_train = roc_auc_score(y_train, model.predict_proba(X_train)[:, 1])

print(f"Training Accuracy: {accuracy_train:.2f}")
print(f"Training Precision: {precision_train:.2f}")
print(f"Training Recall: {recall_train:.2f}")
print(f"Training AUC: {auc_train:.2f}")
print("Training Classification Report:")
print(classification_report(y_train, y_pred_train))
# Out:
# 5-Fold Cross-Validation Accuracy: 0.93
# Test Accuracy: 0.94
# Test Precision: 0.93
# Test Recall: 0.94
# Test AUC: 0.98
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      1746
#            1       0.93      0.94      0.94      1634
#
#     accuracy                           0.94      3380
#    macro avg       0.94      0.94      0.94      3380
# weighted avg       0.94      0.94      0.94      3380
#
# Training Accuracy: 0.96
# Training Precision: 0.95
# Training Recall: 0.97
# Training AUC: 0.99
# Training Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      4149
#            1       0.95      0.97      0.96      3736
#
#     accuracy                           0.96      7885
#    macro avg       0.96      0.96      0.96      7885
# weighted avg       0.96      0.96      0.96      7885

# %%
import pickle


model_pipeline = {
    'scaler': scaler,
    'model': model,
    # 'pca' : pca
}

with open('trained_model_v7.pkl', 'wb') as file:
    pickle.dump(model_pipeline, file)

print("Model saved successfully to trained_model.pkl")
# Out:
# Model saved successfully to trained_model.pkl
